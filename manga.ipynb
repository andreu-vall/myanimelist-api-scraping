# %% [markdown]
# ## MAL API Setup

# %%
import requests

api_url = 'https://api.myanimelist.net/v2'

# A Client ID is needed (https://myanimelist.net/apiconfig)
with open('client_id.txt', 'r') as f:
    CLIENT_ID = f.read()

headers = {'X-MAL-CLIENT-ID': CLIENT_ID}

def get_data(endpoint, params=None):
    url = api_url + endpoint
    if params:
        url += '?' + '&'.join(f'{key}={value}' for key, value in params.items())
    response = requests.get(url, headers=headers)
    response.raise_for_status()
    return response.json()

# %% [markdown]
# ## Scrap Manga

# %%
import json
import os

scraping_save_pages = 'data/data_tmp/manga_pages'

if not os.path.exists(scraping_save_pages): # Create saving directory if it doesn't exist
  os.makedirs(scraping_save_pages)

endpoint = f'/manga/ranking'
limit = 500

manga_keys = ['id', 'title', 'main_picture', 'alternative_titles', 'start_date', 'end_date', 'synopsis', 'mean', 'rank', 'popularity',
              'num_list_users', 'num_scoring_users', 'num_favorites', 'nsfw', 'genres', 'created_at', 'updated_at', 'media_type', 'status',
              'num_volumes', 'num_chapters', 'authors{first_name,last_name}']

def scrape_page(page):
    params = {'ranking_type': 'favorite', 'limit': limit, 'offset': page*limit, 'fields': ','.join(manga_keys)}
    data = get_data(endpoint, params)
    useful = [manga['node'] for manga in data['data']]
    with open(scraping_save_pages + f'/page{str(page).zfill(3)}.json', 'w') as f:
        json.dump(useful, f, indent=4)

# %%
import math

# 22 June 2022
previous_total_manga = 66_506
previous_last_page = math.ceil(previous_total_manga / limit) - 1

data = get_data(endpoint, {'ranking_type': 'favorite', 'limit': limit, 'offset': previous_last_page*limit, 'fields': ','.join(manga_keys)})
assert len(data['data']) > 0
assert 'next' not in data['paging']

last_page = previous_last_page

last_page
# Out:
# 132

# %%
import tqdm
import time

for page in tqdm.trange(1):
    scrape_page(page)
    time.sleep(1)
# Out:
# 100%|██████████| 1/1 [00:04<00:00,  4.13s/it]

# %%
import tqdm
import time

for page in tqdm.trange(last_page+1):   # Crashed in pages: 66, 82, 93, 96, 101 (had to scrap them without requesting the field alternative_titles
    scrape_page(page)                   # Some Manga might not have the alternative_tiltes key correctly and asking for it makes the request crash?
    time.sleep(1)
# Out:
# 100%|██████████| 31/31 [01:37<00:00,  3.14s/it]

# %% [markdown]
# ## Merge Files

# %%
import os

scraping_save_pages = 'data/data_tmp/manga_pages'

data = []
for file_name in os.listdir(scraping_save_pages):
    file_path = os.path.join(scraping_save_pages, file_name)
    with open(file_path, 'r') as f:
        file = json.load(f)
    data.extend(file)

len(data)
# Out:
# 500

# %%
with open('data/data_tmp/manga_raw.json', 'w') as f:
    json.dump(data, f, indent=4)

# %% [markdown]
# ## Manga cleaning

# %%
import pandas as pd
import numpy as np
import json

with open('data/data_tmp/manga_raw.json', 'r') as f:
    data = json.load(f)

manga = pd.json_normalize(data, sep='_')

# %%
import pandas as pd
import numpy as np
import json

with open('data/data_tmp/manga_raw.json', 'r') as f:
    data = json.load(f)

manga = pd.json_normalize(data, sep='_')

# Remove 12 duplcated in the first data gathering (avoid in the next iteration)
manga = manga.drop_duplicates(subset=['id']).reset_index().drop(columns='index')

# Use Timestamps
manga['start_date'] = pd.to_datetime(manga['start_date'])
manga['end_date'] = pd.to_datetime(manga['end_date'])

# Avoid floats and zeroes marking nsfw
manga['rank'] = manga['rank'].replace(0, np.nan).astype('Int64')
manga['popularity'] = manga['popularity'].replace(0, np.nan).astype('Int64')
manga['num_volumes'] = manga['num_volumes'].replace(0, np.nan).astype('Int64')
manga['num_chapters'] = manga['num_chapters'].replace(0, np.nan).astype('Int64')

# Only keep names
manga['genres'] = manga['genres'].apply(lambda x: [dic['name'] for dic in x] if not x is np.nan else [])

# Missing author names!!!
#manga['authors'] = manga['authors'].apply(lambda x: [{'author_id': dic['node']['id'], 'role': dic['role']} for dic in x] if not x is np.nan else [])

# MyAnimeList edits
manga['created_at'] = pd.to_datetime(manga['created_at']).dt.tz_convert(None)
manga['updated_at'] = pd.to_datetime(manga['updated_at']).dt.tz_convert(None)

# Avoid empty string
manga.loc[manga['synopsis'].isin(['', ' ', 'N/A', 'n/a']), 'synopsis'] = np.nan
manga.loc[manga['alternative_titles_en'].isin(['', 'N/A']), 'alternative_titles_en'] = np.nan
manga['alternative_titles_ja'] = manga['alternative_titles_ja'].replace('', np.nan)
manga['alternative_titles_synonyms'] = manga['alternative_titles_synonyms'].fillna('').apply(list)


order = ['id', 'title', 'media_type', 'mean', 'num_scoring_users',                          # 10 Most important attributes,
         'status', 'num_volumes', 'num_chapters', 'start_date', 'end_date',                 # appearing first on kaggle

         'num_list_users', 'popularity', 'num_favorites', 'rank',                           # Other important attrubtes
         
         'genres', 'authors',                                                               # Multivalued attributes
         'synopsis', 'nsfw', 'created_at', 'updated_at',                                    # Description, MyAnimeList edits

         'main_picture_medium', 'main_picture_large',                                       # Media data
         'alternative_titles_en', 'alternative_titles_ja', 'alternative_titles_synonyms']   # Other titles


manga = manga[order]

# Save to csv
manga.to_csv('data/manga.csv', index=False)

pd.options.display.max_columns = None
manga.head(1)
# Out:
#    id    title media_type  mean  num_scoring_users                status  \
# 0   2  Berserk      manga  9.45             262200  currently_publishing
#
#    num_volumes  num_chapters start_date end_date  num_list_users  popularity  \
# 0         <NA>          <NA> 1989-08-25      NaT          539414           2
#
#    num_favorites  rank                                             genres  \
# 0         101608     1  [Action, Adventure, Award Winning, Drama, Fant...
#
#                                              authors  \
# 0  [{'node': {'id': 1868, 'first_name': 'Kentarou...
#
#                                             synopsis   nsfw created_at  \
# 0  Guts, a former mercenary now known as the "Bla...  white 1970-01-01
#
#            updated_at                                main_picture_medium  \
# 0 2022-06-23 08:30:44  https://api-cdn.myanimelist.net/images/manga/1...
#
#                                   main_picture_large alternative_titles_en  \
# 0  https://api-cdn.myanimelist.net/images/manga/1...               Berserk
#
#   alternative_titles_ja alternative_titles_synonyms
# 0                 ベルセルク    [Berserk: The Prototype]

# %%
manga[manga['authors'].str[0].str['node'].str['first_name']=='']
# Out:
#          id                                      title   media_type  mean  \
# 8    121496                              Solo Leveling       manhwa  8.73
# 45    24692                                   Noragami        manga  8.42
# 47   122663                               Tower of God       manhwa  8.44
# 77   110737                   Ijiranaide, Nagatoro-san        manga  7.69
# 90        9               Tsubasa: RESERVoir CHRoNiCLE        manga  8.31
# 459 2016-09-30        NaT           27219         524            978  1067
# 460 2012-12-12        NaT           43198         320            976  1783
# 461 2015-06-25        NaT           24113         595            974  1407
# 463 2012-05-30 2017-12-29           11641        1376            968   602
# 471 1992-03-24 2003-03-24           21974         658            945   511
# 495 2017-11-25 2020-08-07           15549         974            864  <NA>
#
#                                                 genres  \
# 8                         [Action, Adventure, Fantasy]
# 45               [Action, Fantasy, Mythology, Shounen]
# 47        [Action, Adventure, Drama, Fantasy, Mystery]
# 77   [Comedy, Romantic Subtext, School, Slice of Li...
# 90        [Action, Adventure, Drama, Fantasy, Shounen]
# 102                   [Fantasy, Isekai, Reincarnation]
# 107  [Adult Cast, Comedy, Otaku Culture, Romance, W...
# 111  [Action, Award Winning, Comedy, Super Power, S...
# 118     [Comedy, Drama, Mystery, Seinen, Supernatural]
# 121               [Drama, Erotica, Girls Love, School]
# 122  [Action, Award Winning, Ecchi, School, Shounen...
# 130  [Adventure, Award Winning, Iyashikei, Slice of...
# 154  [Adventure, Award Winning, Comedy, Fantasy, Ma...
# 160                  [Comedy, Romance, School, Shoujo]
# 161    [Award Winning, Romance, Shoujo, Slice of Life]
# 163  [Action, Adventure, Fantasy, Romance, Video Game]
# 174             [Action, Comedy, Drama, Ecchi, Seinen]
# 177  [Boys Love, Drama, Erotica, Horror, Psychologi...
# 193                       [Action, Adventure, Fantasy]
# 202                         [Romance, School, Shounen]
# 208  [Comedy, Ecchi, Psychological, Romance, Sci-Fi...
# 232  [Action, Adult Cast, Drama, Organized Crime, S...
# 233          [Comedy, Fantasy, Reincarnation, Romance]
# 239        [Comedy, Girls Love, School, Slice of Life]
# 250                            [Shounen, Supernatural]
# 251                  [Action, Drama, Military, Sci-Fi]
# 253                             [Action, Martial Arts]
# 278          [Comedy, Harem, Romance, School, Shounen]
# 285   [Action, Horror, Romance, Supernatural, Vampire]
# 302  [Award Winning, Comedy, Mahou Shoujo, Romance,...
# 303      [CGDCT, Comedy, Music, School, Slice of Life]
# 310                   [Fantasy, Isekai, Reincarnation]
# 321  [Horror, Mystery, Romance, School, Shounen, Su...
# 339  [Romantic Subtext, Shounen, Supernatural, Vamp...
# 349  [Action, Comedy, Drama, Mystery, Romance, Shou...
# 357     [Drama, Fantasy, Horror, Mahou Shoujo, School]
# 374                           [Fantasy, Slice of Life]
# 380          [Boys Love, Drama, School, Slice of Life]
# 410      [Crossdressing, Drama, Love Polygon, Romance]
# 421              [Seinen, Slice of Life, Supernatural]
# 456  [Award Winning, Comedy, Otaku Culture, Reverse...
# 459                                            [Drama]
# 460  [Action, High Stakes Game, Mystery, Shounen, S...
# 461               [Action, Adventure, Fantasy, Isekai]
# 463                    [Comedy, Sci-Fi, Slice of Life]
# 471  [Action, Drama, Fantasy, Psychological, Shoujo...
# 495                        [Boys Love, Drama, Erotica]
#
#                                                authors  \
# 8    [{'node': {'id': 49667, 'first_name': '', 'las...
# 45   [{'node': {'id': 6644, 'first_name': '', 'last...
# 47   [{'node': {'id': 49934, 'first_name': '', 'las...
# 77   [{'node': {'id': 27461, 'first_name': '', 'las...
# 90   [{'node': {'id': 1877, 'first_name': '', 'last...
# 102  [{'node': {'id': 30675, 'first_name': '', 'las...
# 107  [{'node': {'id': 37903, 'first_name': '', 'las...
# 111  [{'node': {'id': 16993, 'first_name': '', 'las...
# 118  [{'node': {'id': 1877, 'first_name': '', 'last...
# 121  [{'node': {'id': 20176, 'first_name': '', 'las...
# 122  [{'node': {'id': 1932, 'first_name': '', 'last...
# 130  [{'node': {'id': 8886, 'first_name': '', 'last...
# 154  [{'node': {'id': 1877, 'first_name': '', 'last...
# 160  [{'node': {'id': 8512, 'first_name': '', 'last...
# 161  [{'node': {'id': 5632, 'first_name': '', 'last...
# 163  [{'node': {'id': 10742, 'first_name': '', 'las...
# 174  [{'node': {'id': 3537, 'first_name': '', 'last...
# 177  [{'node': {'id': 49338, 'first_name': '', 'las...
# 193  [{'node': {'id': 53209, 'first_name': '', 'las...
# 202  [{'node': {'id': 5811, 'first_name': '', 'last...
# 208  [{'node': {'id': 1877, 'first_name': '', 'last...
# 232  [{'node': {'id': 12247, 'first_name': '', 'las...
# 233  [{'node': {'id': 49714, 'first_name': '', 'las...
# 239  [{'node': {'id': 16477, 'first_name': '', 'las...
# 250  [{'node': {'id': 38493, 'first_name': '', 'las...
# 251  [{'node': {'id': 18819, 'first_name': '', 'las...
# 253  [{'node': {'id': 25033, 'first_name': '', 'las...
# 278  [{'node': {'id': 12593, 'first_name': '', 'las...
# 285  [{'node': {'id': 2582, 'first_name': '', 'last...
# 302  [{'node': {'id': 1948, 'first_name': '', 'last...
# 303  [{'node': {'id': 7362, 'first_name': '', 'last...
# 310  [{'node': {'id': 37294, 'first_name': '', 'las...
# 321  [{'node': {'id': 8576, 'first_name': '', 'last...
# 339  [{'node': {'id': 33067, 'first_name': '', 'las...
# 349  [{'node': {'id': 1932, 'first_name': '', 'last...
# 357  [{'node': {'id': 9496, 'first_name': '', 'last...
# 374  [{'node': {'id': 25227, 'first_name': '', 'las...
# 380  [{'node': {'id': 50320, 'first_name': '', 'las...
# 410  [{'node': {'id': 18025, 'first_name': '', 'las...
# 421  [{'node': {'id': 22323, 'first_name': '', 'las...
# 456  [{'node': {'id': 10867, 'first_name': '', 'las...
# 459  [{'node': {'id': 44361, 'first_name': '', 'las...
# 460  [{'node': {'id': 9553, 'first_name': '', 'last...
# 461  [{'node': {'id': 10907, 'first_name': '', 'las...
# 463  [{'node': {'id': 18249, 'first_name': '', 'las...
# 471  [{'node': {'id': 1877, 'first_name': '', 'last...
# 495  [{'node': {'id': 53789, 'first_name': '', 'las...
#
#                                               synopsis   nsfw created_at  \
# 8    Ten years ago, "the Gate" appeared and connect...  white 1970-01-01
# 45   As a relatively unknown minor deity without an...  white 1970-01-01
# 47   Twenty-Fifth Bam had been alone his whole life...  white 1970-01-01
# 77   High schooler Hayase Nagatoro loves to spend h...  white 1970-01-01
# 90   Warmhearted Syaoran has always been friends wi...  white 1970-01-01
# 102  Killed while saving a stranger from a traffic ...  white 1970-01-01
# 107  Narumi Momose is a petite and cute young woman...  white 1970-01-01
# 111  Shigeo "Mob" Kageyama is an eighth-grade stude...  white 1970-01-01
# 118  Living alone after his parents passed away, Ki...  white 1970-01-01
# 130                                  Girls' Last Tour
# 154                                 Cardcaptor Sakura
# 160                                 My Little Monster
# 161                                  House of the Sun
# 163                                  Sword Art Online
# 174                                      Sun-Ken Rock
# 177                                  Killing Stalking
# 193                                 Omniscient Reader
# 202                                         Blue Flag
# 208                                           Chobits
# 232                                          Gangsta.
# 233                                               NaN
# 239                                               NaN
# 250        The Girl From the Other Side: Siúil, a Rún
# 251                                     86—Eighty-Six
# 253                                     Kengan Ashura
# 278                            Masamune-kun's Revenge
# 285                            Lunar Legend Tsukihime
# 302                                      Shugo Chara!
# 303                                             K-On!
# 310           That Time I Got Reincarnated as a Slime
# 321                                               NaN
# 339                                 Call of the Night
# 349                                    Bakemonogatari
# 357                         Puella Magi Madoka★Magica
# 374                      Miss Kobayashi's Dragon Maid
# 380                                               NaN
# 410     The boy who cried wolf tells a lie today also
# 421                                     Shadows House
# 456                                  Kiss Him, Not Me
# 459                             One Room of Happiness
# 460                                               NaN
# 461  Arifureta: From Commonplace to World's Strongest
# 463                                      Kagerou Daze
# 471                                                 X
# 495                                           BJ Alex
#
#          alternative_titles_ja  \
# 8                    나 혼자만 레벨업
# 45                        ノラガミ
# 47                        신의 탑
# 77                 イジらないで、長瀞さん
# 90   ツバサ -RESERVoir CHRoNiCLE-
# 102         無職転生 ～異世界行ったら本気だす～
# 107                  ヲタクに恋は難しい
# 111                   モブサイコ100
# 118                   xxxHOLiC
# 121                     citrus
# 122                      エア・ギア
# 130                     少女終末旅行
# 154                カードキャプターさくら
# 160                   となりの怪物くん
# 161                    たいようのいえ
# 163               ソードアート・オンライン
# 174                    サンケンロック
# 177                     킬링 스토킹
# 193                  전지적 독자 시점
# 202                     青のフラッグ
# 208                      ちょびっツ
# 232                   GANGSTA.
# 233             어느 날 공주가 되어버렸다
# 239                  SQ从你的名字开始
# 250                    とつくにの少女
# 251               86―エイティシックス―
# 253                   ケンガンアシュラ
# 278                  政宗くんのリベンジ
# 285                     真月譚 月姫
# 302                    しゅごキャラ！
# 303                      けいおん!
# 310              転生したらスライムだった件
# 321                 黄昏乙女×アムネジア
# 339                    よふかしのうた
# 349                        化物語
# 357                魔法少女まどか★マギカ
# 374               小林さんちのメイドラゴン
# 380                 Here U Are
# 410               狼少年は今日も嘘を重ねる
# 421                    シャドーハウス
# 456                 私がモテてどうすんだ
# 459                   幸色のワンルーム
# 460                  ダーウィンズゲーム
# 461               ありふれた職業で世界最強
# 463                    カゲロウデイズ
# 471                          X
# 495                     BJ 알렉스
#
#                            alternative_titles_synonyms
# 8             [Na Honjaman Level Up, I Level Up Alone]
# 45                                        [Stray Gods]
# 47                                        [Sin-ui Tap]
# 77                   [Please don't bully me, Nagatoro]
# 90                                               [TRC]
# 102                                                 []
# 107                  [It's Difficult to Love an Otaku]
# 111                           [One Hundred Mob Psycho]
# 118                      [xxxHolic Rou, xxxHolic Cage]
# 121                                                 []
# 122                      [AirGear, Air Gear Unlimited]
# 130                                [The End Girl Trip]
# 154       [Cardcaptor Sakura: Master of the Clow, CCS]
# 160  [Tonari no Kaibutsukun, The Monster Next Door,...
# 161                                                 []
# 163                                       [S.A.O, SAO]
# 174                           [Trigun: The Lost Plant]
# 177                                                 []
# 193  [Omniscient Reader's Viewpoint, Jeonji-jeok Do...
# 202                                                 []
# 208                                                 []
# 232                                                 []
# 233  [Eoneu Nal Gongjuga Doeeo Beoryeotda, Suddenly...
# 239  [Their Story, Tamen De Gushi, SQ: Cong Ni De M...
# 250                                     [Foreign Girl]
# 251                                       [Eighty Six]
# 253                                                 []
# 278                                                 []
# 285  [True Lunar Chronicle Tsukihime, Lunar Legend ...
# 302                             [Shugo Chara! Encore!]
# 303                                            [Keion]
# 310                                          [TenSura]
# 321   [Koukin Otome x Amnesia, Dusk Maiden of Amnesia]
# 339                                                 []
# 349    [Monster Tale, Monogatari Series: First Season]
# 357  [Mahou Shoujo Madoka Magika, Magical Girl Mado...
# 374                 [The maid dragon of Kobayashi-san]
# 380                             [Yuanlai Ni Zai Zheli]
# 410                                                 []
# 421                                                 []
# 456  [Boys, Please Kiss Him Instead of Me, What wil...
# 459                                                 []
# 460                                                 []
# 461  [From Common Job Class to the Strongest in the...
# 463                     [Kagerou Days, Heat-Haze Days]
# 471                                           [X/1999]
# 495                                            [BJ MD]

# %%
manga['authors'].str[0].str['node'].str['first_name'].value_counts()
# Out:
#             47
# Hirohiko     8
# Hiro         6
# Yuki         6
# Kentarou     5
#             ..
# Sorata       1
# Kamome       1
# Hiroaki      1
# Aya          1
# Kanna        1
# Name: authors, Length: 306, dtype: int64

# %%
manga.loc[0, 'authors']
# Out:
# [{'node': {'id': 1868, 'first_name': 'Kentarou', 'last_name': 'Miura'},
#   'role': 'Story & Art'},
#  {'node': {'id': 49592, 'first_name': '', 'last_name': 'Studio Gaga'},
#   'role': 'Art'}]

# %% [markdown]
# # Load Manga

# %%
from ast import literal_eval
import pandas as pd

manga = pd.read_csv('data/manga.csv')

columns_dtype_datetime = ['start_date', 'end_date', 'created_at', 'updated_at']
for col in columns_dtype_datetime:
    manga[col] = pd.to_datetime(manga[col])

columns_dtype_Int64 = ['num_volumes', 'num_chapters', 'popularity', 'rank']
for col in columns_dtype_Int64:
    manga[col] = manga[col].astype('Int64')

columns_dtype_list = ['genres', 'authors', 'alternative_titles_synonyms']
for col in columns_dtype_list:
    manga[col] = manga[col].apply(literal_eval)

manga.head(1)
# Out:
#    id    title media_type  mean  num_scoring_users     status  num_volumes  \
# 0   2  Berserk      manga  9.45             261724  on_hiatus           41
#
#    num_chapters start_date   end_date  num_list_users  popularity  \
# 0           380 1989-08-25 2021-09-10          538522           2
#
#    num_favorites  rank                                             genres  \
# 0         101419     1  [Action, Adventure, Award Winning, Drama, Fant...
#
#                                         authors  \
# 0  [{'author_id': 1868, 'role': 'Story & Art'}]
#
#                                             synopsis   nsfw created_at  \
# 0  Guts, a former mercenary now known as the "Bla...  white 1970-01-01
#
#            updated_at                                main_picture_medium  \
# 0 2022-06-08 23:10:04  https://api-cdn.myanimelist.net/images/manga/1...
#
#                                   main_picture_large alternative_titles_en  \
# 0  https://api-cdn.myanimelist.net/images/manga/1...               Berserk
#
#   alternative_titles_ja alternative_titles_synonyms
# 0                 ベルセルク    [Berserk: The Prototype]
